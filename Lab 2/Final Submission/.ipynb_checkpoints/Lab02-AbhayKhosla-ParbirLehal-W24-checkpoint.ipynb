# %% [markdown]
# <!-- DON'T EDIT THIS CELL! -->
# <!-- TYPE SHIFT+ENTER AND GO TO THE NEXT CELL -->
#
# <img src="data:image/png;base64,..." />

# %% [markdown]
# # Lab 2 - Report

# %% [markdown]
# #### UCID 1: 30085789
# #### Name 1: Abhay Khosla
#
# #### UCID 2: 30096001
# #### Name 2: Parbir Lehal
#
# #### Group Number: 07

# %% [markdown]
# ### Readme
# We are submitting the signature_samples folder zipped with our data that contains the genuine and impostor version of the word we wrote "labs". Note they are some depreciation warnings but they do not affect the code or the output.

# %% [markdown]
# ## Introduction
# In biometrics one of the key aspect is identity recognition we mainly will be focusing on identification of words such as "Labs" and another word "Four" in this lab report. Identification means to having many templates and matching it to the submitted input data. We generally perform a lookup in the database to check if the person is impostor or not. This can be used for positive and negative recognition of the person. Another concept which will be covered is verification which identifies samples into two classes genuine user or impostor. This differs from identification because in here we only have one to one comparison. During the lab session we got to explore and understanding the inner working of signature data acquisition in our case we used words and through this report we will take a look at the underlying statistical analysis. During the lab we performed a collection of genuine and forged word samples.

# %%
# Required libraries for Lab 2
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
from mpl_toolkits import mplot3d
import pandas as pd
from scipy.stats import norm

# to keep a good size for the plot figure, not the plot area!
from matplotlib import rcParams
rcParams.update({'figure.autolayout': True})

# %% [markdown]
# **Exercise 1** (2 marks): Consider a random sample of a normally distributed data with mean $\mu = 50$ and standard deviation $\sigma = 5$. The Scipy's function `norm.rvs(...)` is used to draw samples from a normal distribution.
# - Create another set of 1000 samples with $\mu = 50$ and $\sigma = 5$.
# - Plot the histogram with 100 bins.
# - Compare the results of the calculations of both sets. What conclusions can be drawn from the amount of samples compared with the mean and standard deviation calculated and the number of bins considered?

# %%
# Exercise 1
# Theorectical Mean and Std
mu = 50
std = 5
qtt_samples1 = 80
# Exercise 1 creating another set of samples 
qtt_samples2 = 1000

pop_norm1 = norm.rvs(mu, std, size=qtt_samples1)
# Exercise 1 creating another population 
pop_norm2 = norm.rvs(mu, std, size=qtt_samples2)

# %% [markdown]
# ### Population Normal 1 Histogram of 80 samples and 10 bins

# %%
# As mentioned in the lab document that we need to plot the sample 1 with 10 bins
plt.hist(pop_norm1, density=True, bins=10)
print('REAL mean: %.2f; std: %.2f' % (np.mean(pop_norm1), np.std(pop_norm1)))
plt.title("Histogram 80 samples")
# Out:
# REAL mean: 49.32; std: 5.32
# Text(0.5, 1.0, 'Histogram 80 samples')

# %% [markdown]
# ### Population Normal 1 Histogram of 1000 samples and 100 bins

# %%
# Need to specify the bins as mentioned in Ex 1 
plt.hist(pop_norm2, density=True, bins=100)
print('REAL mean: %.2f; std: %.2f' % (np.mean(pop_norm2), np.std(pop_norm2)))
plt.title("Histogram 1000 samples")
# Out:
# REAL mean: 50.05; std: 5.08
# Text(0.5, 1.0, 'Histogram 1000 samples')

# %% [markdown]
# | Statistics |      Pop Norm 1     |  Pop Norm 2 |
# |----------|:-------------:|------:|
# | Real Mean |  51.02 | 50.15 |
# | Standard Deviation |    5.06  |   5.05 |

# %% [markdown]
# ### Combined Histograms of Population Normal 1 and Population Normal 2

# %%
plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
plt.hist(pop_norm1, bins=10, density=True)
plt.hist(pop_norm2, bins=100, density=True, color='orange')
plt.title('Histograms')
plt.legend(['Sample Size 1: 80', 'Sample Size 2: 1000'])

# %% [markdown]
# ### Combined Normal Distributions of Population Normal 1 and Population Normal 2

# %%
mu1, std1 = 50.47, 4.72 # blue
mu2, std2 = 50.47, 5.24 # orange
x1 = np.arange(-25, 90, 0.01)
plt.plot(x1, norm.pdf(x1, loc=mu1, scale=std1))
plt.plot(x1, norm.pdf(x1, loc=mu2, scale=std2), color='orange')
plt.legend(['Mean 1 : 51.02, Std 1: 5.06', 'Mean 2: 50.15, Std 2: 5.05'])
plt.title('Normal Distributions')
# Out:
# Text(0.5, 1.0, 'Normal Distributions')

# %% [markdown]
# ### Comparsion of Population Normal 1 and Population Normal 2 Standard Deviation and Mean with Histograms and Normal Distributions Curves
# As seen in the combined histograms a larger sample size, the calculate mean and standard deviation are more likely to converge to the population's true parameters, this is evident from this histogram as the larger sample size provides a smoother and more bell-shaped distribution which is a characteristic of the normal distribution. The histogram with 80 samples has fewer bins and appears more blocky and less smooth. In contrast, the histogram with 1000 samples has more bins and presents a more detailed picture of the distribution, including its variability. Both curves have similar means (around 50.47), indicating that both sample sizes provided a similar estimate of the population mean. However, the standard deviation is slightly higher in the second curve, which may be due to the larger sample size capturing more of the variability present in the population.

# %% [markdown]
# **Exercise 2** (1 marks): Consider a sample data of the word *Biometrics* written by a "genuine" person, and an "impostor" as a signature that replicates the shape but not the original pressure. Load the sample signature provided. Plot the signature in 2D with the color representing the pressure on each point. Similarly to calculation of the mean and std of the random data, calculate the mean and std of the pressure for one signature, and plot the Normal distribution.

# %%
# data folder:
# 'signature_samples/biometrics/'
# 'signature_samples/calgary/'
# 'signature_samples/hello/'
# Exercise 2-word lab
# 'signature_samples/labs/'

# 'genuine' or 'impostor'
subdir = 'impostor/'
data_dir = 'signature_samples/biometrics/' + subdir

csv_file = pd.read_csv(data_dir + '1.csv')

coord1 = csv_file[['X', 'Y']].to_numpy()
time1 = csv_file['Time'].to_numpy().reshape((-1,1))
prs1 = csv_file['Pressure'].to_numpy().reshape((-1,1))

# %% [markdown]
# ## Plotting based on Pressure and Color Map

# %%
# to correctly map the pressure into the colormap the normalization is required 
prs1 = prs1 / np.max(prs1) * 255
prs1 = prs1.astype(int)
pressuremap = cm.get_cmap('jet', np.max(prs1)+1)
# Out:
# /var/folders/37/q_fxhxq90_d06y854bb7r8lw0000gn/T/ipykernel_1861/696259443.py:4: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   pressuremap = cm.get_cmap('jet', np.max(prs1)+1)

# %%
for i in range(len(prs1)-1):
    c = pressuremap(prs1[i]).squeeze()
    im = plt.plot(coord1[i:i+2,0], -coord1[i:i+2,1], c=c)

plt.xlabel('X')
plt.ylabel('Y')
plt.title('Pen pressure color map')

sm = cm.ScalarMappable(cmap='jet', norm=plt.Normalize(vmin=0, vmax=1))
plt.colorbar(sm)
# Out:
# /var/folders/37/q_fxhxq90_d06y854bb7r8lw0000gn/T/ipykernel_1861/3323017129.py:10: MatplotlibDeprecationWarning: Unable to determine Axes to steal space for Colorbar. Using gca(), but will raise in the future. Either provide the *cax* argument to use as the Axes for the Colorbar, provide the *ax* argument to steal space from it, or add *mappable* to an Axes.
#   plt.colorbar(sm)

# %% [markdown]
# ### Calculating Mean and Standard Deviation of Pressure of one Sample Signature

# %%
mu_prs = np.mean(prs1)
std_prs = np.std(prs1)
print(mu_prs, std_prs)
# Out:
# 210.82958665699783 33.413596352704396

# %% [markdown]
# ### Plotting Normal Distribution of Pressure of one Sample Signature

# %%
x = np.arange(0, 300, 0.01)
x_pdf = norm.pdf(x, loc=mu_prs, scale=std_prs)
plt.plot(x, x_pdf)
plt.title('Smooth Normal Distribution of Pressure of one Sample Signature')
plt.xlabel('Pressure')
plt.ylabel('Probability Density')
plt.grid(True)

# %% [markdown]
# The following mean and standard deviation are from one sample signature sample of the word "biometrics":

# %% [markdown]
# Mean: 210.83, Standard Deviation: 33.41

# %% [markdown]
# This probability density function indicates the likelihood of different pressure levels during the signing process.The curve's peak corresponds to the most likely pressure value, which is the mean of the data set. The distribution appears to be symmetric around this peak, which means that the pressure values during signature creation are as likely to be above as they are to be below the mean.

# %% [markdown]
# **Exercise 3** (1 mark): The code to calculate velocity and plot velocity map of one signature, provided in this lab, has the following `if` statement: `if time_diff == 0:`.
# - Explain why it is necessary.
# - Plot in 3D, where the third coordinate represents pressure.

# %%
#Exercise 3
vel = np.zeros((len(time1)-1, 1))
for i in range (len(time1)-1):
    distance = np.sqrt((coord1[i+1,0] - coord1[i,0])**2 + (coord1[i+1,1] - coord1[i,1])**2)
    # if too fast , time diff = 0
    time_diff = abs(time1 [i+1] - time1[i])
    if time_diff != 0:
        vel[i] = distance / time_diff
    vel[i] = int(vel[i] * 1000) + 1

vel = np.insert(vel, 0, 1)
vel = vel / np.max(vel) * 255
vel = vel.astype(int)

velmap = cm.get_cmap('jet', np.max(vel)+1)

for i in range(len(vel)-1):
    c = velmap(vel[i])
    if time_diff < 17: # You may need to change this threshould
        im = plt.plot(coord1[i:i+2,0], -coord1[i:i+2,1], c=c)
plt.title('Velocity color map')

sm = cm.ScalarMappable(cmap='jet', norm=plt.Normalize(vmin=0, vmax=1))
plt.colorbar(sm)
# Out:
# /var/folders/37/q_fxhxq90_d06y854bb7r8lw0000gn/T/ipykernel_1861/2876036020.py:15: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   velmap = cm.get_cmap('jet', np.max(vel)+1)
# /var/folders/37/q_fxhxq90_d06y854bb7r8lw0000gn/T/ipykernel_1861/2876036020.py:24: MatplotlibDeprecationWarning: Unable to determine Axes to steal space for Colorbar. Using gca(), but will raise in the future. Either provide the *cax* argument to use as the Axes for the Colorbar, provide the *ax* argument to steal space from it, or add *mappable* to an Axes.
#   plt.colorbar(sm)

# %% [markdown]
# The ```time_diff``` not equal to zero is so that we can avoid errors while doing an integer division which is undefined mathematically and would cause an error in the program. In the context of this script, a ```time_diff``` of zero means that the two points being compared are recorded at the same time instant, implying an infinite velocity, which is not possible.

# %% [markdown]
# ### Plotting Pen Pressure in 3D

# %%
ax = plt.axes( projection ='3d')
# the line below is to reshape to vector using .flatten method
ax.plot3D(coord1[: ,0].flatten(), -coord1[: ,1].flatten(), prs1.flatten())
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Pressure')
ax.set_title('Pen pressure in 3D')
# Out:
# Text(0.5, 0.92, 'Pen pressure in 3D')

# %% [markdown]
# **Exercise 4** (3 marks): Now  perform statistical analysis of pressure and velocity distribution  across average values of pressure or 30 signatures of the same person. We will represent the pressure of each signature by its average (mean) value, and then consider the distribution of these average values across genuine signatures. Consider 30 genuine signatures (yours or pre-recorded sample set, part a), and calculate average (mean) values and deviation from average (which will be calculated using standard deviation) for pressure. Plot a normal distribution of the average pressure values across the 30 signatures of the same individual. Perform the same for velocity.

# %%
# Loading the genuine data of the word "lab"
subdir_genuine = 'genuine/'
data_dir_genuine = './signature_samples/labs/' + subdir_genuine

# %%
#Exercise 4
def calc_velocity(time , coords ):
    vel = np.zeros((len(time)-1, 1))

    for i in range(len(time)-1):
        distance = np.sqrt((coords[i+1,0] - coords[i,0])**2 + ( coords[i+1,1] - coords[i,1])**2)

        # if too fast time diff = 0
        time_diff = time[i+1] - time[i]
        if time_diff == 0:
            time_diff = 0.0001

        vel[i] = distance / time_diff
        vel[i] = int(vel[i] * 1000) + 1

    vel = np.insert(vel, 0, 1)
    vel = vel/np.max(vel) * 255
    vel = vel.astype(int)
    return vel

# %%
# columns : mean vel, std vec, mean prs, std prs
stats_measures = np.zeros((30,4))

# using 30 genuine signatures
for i in range(30):
    csv_file = pd.read_csv(data_dir_genuine + '%d.csv' % (i+1))
    coord1 = csv_file[['X', 'Y']].to_numpy()
    time1 = csv_file['Time'].to_numpy().reshape((-1,1))
    prs1 = csv_file['Pressure'].to_numpy().reshape((-1,1))
    vel = calc_velocity(time1, coord1)
    stats_measures[i, 0] = np.mean(vel)
    stats_measures[i, 1] = np.std(vel)
    stats_measures[i, 2] = np.mean(prs1)
    stats_measures[i, 3] = np.std(prs1)
    print('#%d = Pressure Mean: %.2f, Pressure Standard Deviation: %.2f, Velocity Mean: %.2f, Velocity Standard Deviation: %.2f, ' %
          (i, np.mean(prs1), np.std(prs1), np.mean(vel), np.std(vel)))
# Out:
# #0 = Pressure Mean: 0.49, Pressure Standard Deviation: 0.09, Velocity Mean: 23.29, Velocity Standard Deviation: 45.63,
# #1 = Pressure Mean: 0.45, Pressure Standard Deviation: 0.10, Velocity Mean: 14.64, Velocity Standard Deviation: 31.45,
# #2 = Pressure Mean: 0.45, Pressure Standard Deviation: 0.09, Velocity Mean: 28.95, Velocity Standard Deviation: 55.71,
# #3 = Pressure Mean: 0.47, Pressure Standard Deviation: 0.09, Velocity Mean: 18.16, Velocity Standard Deviation: 34.25,
# #4 = Pressure Mean: 0.49, Pressure Standard Deviation: 0.09, Velocity Mean: 34.81, Velocity Standard Deviation: 66.57,
# #5 = Pressure Mean: 0.48, Pressure Standard Deviation: 0.11, Velocity Mean: 27.42, Velocity Standard Deviation: 51.97,
# #6 = Pressure Mean: 0.50, Pressure Standard Deviation: 0.10, Velocity Mean: 21.22, Velocity Standard Deviation: 41.77,
# #7 = Pressure Mean: 0.48, Pressure Standard Deviation: 0.09, Velocity Mean: 28.82, Velocity Standard Deviation: 53.03,
# #8 = Pressure Mean: 0.50, Pressure Standard Deviation: 0.10, Velocity Mean: 32.25, Velocity Standard Deviation: 61.47,
# #9 = Pressure Mean: 0.56, Pressure Standard Deviation: 0.11, Velocity Mean: 28.75, Velocity Standard Deviation: 58.84,
# #10 = Pressure Mean: 0.49, Pressure Standard Deviation: 0.09, Velocity Mean: 34.53, Velocity Standard Deviation: 63.25,
# #11 = Pressure Mean: 0.48, Pressure Standard Deviation: 0.09, Velocity Mean: 35.26, Velocity Standard Deviation: 65.89,
# #12 = Pressure Mean: 0.49, Pressure Standard Deviation: 0.09, Velocity Mean: 28.87, Velocity Standard Deviation: 56.14,
# #13 = Pressure Mean: 0.52, Pressure Standard Deviation: 0.08, Velocity Mean: 32.28, Velocity Standard Deviation: 59.70,
# #14 = Pressure Mean: 0.51, Pressure Standard Deviation: 0.08, Velocity Mean: 32.80, Velocity Standard Deviation: 61.51,
# #15 = Pressure Mean: 0.48, Pressure Standard Deviation: 0.09, Velocity Mean: 41.88, Velocity Standard Deviation: 68.69,
# #16 = Pressure Mean: 0.48, Pressure Standard Deviation: 0.09, Velocity Mean: 28.57, Velocity Standard Deviation: 55.08,
# #17 = Pressure Mean: 0.50, Pressure Standard Deviation: 0.08, Velocity Mean: 30.70, Velocity Standard Deviation: 54.59,
# #18 = Pressure Mean: 0.52, Pressure Standard Deviation: 0.08, Velocity Mean: 27.87, Velocity Standard Deviation: 55.73,
# #19 = Pressure Mean: 0.53, Pressure Standard Deviation: 0.09, Velocity Mean: 30.47, Velocity Standard Deviation: 58.63,
# #20 = Pressure Mean: 0.52, Pressure Standard Deviation: 0.09, Velocity Mean: 30.87, Velocity Standard Deviation: 60.76,
# #21 = Pressure Mean: 0.49, Pressure Standard Deviation: 0.10, Velocity Mean: 31.25, Velocity Standard Deviation: 59.26,
# #22 = Pressure Mean: 0.49, Pressure Standard Deviation: 0.08, Velocity Mean: 36.02, Velocity Standard Deviation: 69.72,
# #23 = Pressure Mean: 0.49, Pressure Standard Deviation: 0.09, Velocity Mean: 27.45, Velocity Standard Deviation: 50.91,
# #24 = Pressure Mean: 0.47, Pressure Standard Deviation: 0.09, Velocity Mean: 32.49, Velocity Standard Deviation: 61.35,
# #25 = Pressure Mean: 0.49, Pressure Standard Deviation: 0.08, Velocity Mean: 28.91, Velocity Standard Deviation: 56.71,
# #26 = Pressure Mean: 0.48, Pressure Standard Deviation: 0.09, Velocity Mean: 28.59, Velocity Standard Deviation: 58.21,
# #27 = Pressure Mean: 0.52, Pressure Standard Deviation: 0.08, Velocity Mean: 37.03, Velocity Standard Deviation: 67.34,
# #28 = Pressure Mean: 0.48, Pressure Standard Deviation: 0.10, Velocity Mean: 34.19, Velocity Standard Deviation: 66.96,
# #29 = Pressure Mean: 0.51, Pressure Standard Deviation: 0.10, Velocity Mean: 30.82, Velocity Standard Deviation: 60.99,

# %% [markdown]
# This is the last Individual Genuine word written "labs" with the following statistics:
# | Statistics |      Pressure     |  Velocity |
# |----------|:-------------:|------:|
# | Mean |  0.51 | 30.82 |
# | Standard Deviation |    0.10   |   60.99 |

# %% [markdown]
# ### Plotting Normal Distribution Graphs for Genuine Pressure and Velocity

# %%
# Plot for Pressure
plt.figure(figsize=(10,5))
x = np.arange(min(stats_measures[:, 2]), max(stats_measures[:, 2]), 0.00125)
x_pdf = norm.pdf(x, loc=np.mean(stats_measures[:, 2]), scale=np.std(stats_measures[:, 2]))
plt.xlabel('Pressure')
plt.ylabel('Probability Density')
plt.title('Normal Distribution of Genuine Pressure')
plt.plot(x, x_pdf)

# Plot for Velocity
plt.figure(figsize=(10,5))
x = np.arange(min(stats_measures[:, 0]), max(stats_measures[:, 0]), 0.01)
x_pdf = norm.pdf(x, loc=np.mean(stats_measures[:, 0]), scale=np.std(stats_measures[:, 0]))
plt.xlabel('Velocity')
plt.ylabel('Probability Density')
plt.title('Normal Distribution of Genuine Velocity')
plt.plot(x, x_pdf)

# %% [markdown]
# The Genuine Pressure Distribution graph shows the average pressure exerted during writing the word "labs", there is no curve visible over the plotted range which means a very small standard deviation (0.10) compared to the mean (0.51), that indicates that there was very little variation in pressure across the samples. The Genuine Velocity Distribution curve is bell-shaped representing a normal distribution, the peak of the curve is related to the mean velocity where the highest amount of data points is found. From the graph, we can guess that the majority of velocities cluster around a central value with fewer occurrences of extreme velocities, which in theory makes sense as an individual writes words at the same speed.

# %% [markdown]
# **Exercise 5** (3 marks): Perform statistical analysis of average pressure and velocity distribution across 30 impostor signatures. As an "impostor", you can use either the 30 "forged" signatures (or part $b$ of the pre-recorded set), or 30 writings by yourself, of different shape/word (or part $c$ of the pre-recorded set). Represent the pressure (or velocity) of each signature by its average (mean), and then consider the distribution of these averages across 30 impostor signatures. How different are those distributions for "genuine" signatures from Exercise 4 and the "impostor" from Exercise 5?

# %%
# Loading the impostor data of the word "lab"
subdir_impostor = 'impostor/'
data_dir_impostor = './signature_samples/labs/' + subdir_impostor

# %%
#Exercise 5
def calc_velocity(time , coords ):
    vel = np.zeros((len(time)-1, 1))

    for i in range(len(time)-1):
        distance = np.sqrt((coords[i+1,0] - coords[i,0])**2 + ( coords[i+1,1] - coords[i,1])**2)

        # if too fast time diff = 0
        time_diff = time[i+1] - time[i]
        if time_diff == 0:
            time_diff = 0.0001

        vel[i] = distance / time_diff
        vel[i] = int(vel[i] * 1000) + 1

    vel = np.insert(vel, 0, 1)
    vel = vel/np.max(vel) * 255
    vel = vel.astype(int)
    return vel

# %%
# columns : mean vel, std vec, mean prs, std prs
stats_measures = np.zeros((30,4))

# using 30 impostor signatures
for i in range(30):
    csv_file = pd.read_csv(data_dir_impostor + '%d.csv' % (i+1))
    coord1 = csv_file[['X', 'Y']].to_numpy()
    time1 = csv_file['Time'].to_numpy().reshape((-1,1))
    prs1 = csv_file['Pressure'].to_numpy().reshape((-1,1))
    vel = calc_velocity(time1, coord1)
    stats_measures[i, 0] = np.mean(vel)
    stats_measures[i, 1] = np.std(vel)
    stats_measures[i, 2] = np.mean(prs1)
    stats_measures[i, 3] = np.std(prs1)
    print('#%d = Pressure Mean: %.2f, Pressure Standard Deviation: %.2f, Velocity Mean: %.2f, Velocity Standard Deviation: %.2f, ' %
          (i, np.mean(prs1), np.std(prs1), np.mean(vel), np.std(vel)))
# Out:
# #0 = Pressure Mean: 0.42, Pressure Standard Deviation: 0.10, Velocity Mean: 26.35, Velocity Standard Deviation: 47.30,
# #1 = Pressure Mean: 0.43, Pressure Standard Deviation: 0.08, Velocity Mean: 30.38, Velocity Standard Deviation: 56.57,
# #2 = Pressure Mean: 0.47, Pressure Standard Deviation: 0.11, Velocity Mean: 25.61, Velocity Standard Deviation: 49.48,
# #3 = Pressure Mean: 0.49, Pressure Standard Deviation: 0.12, Velocity Mean: 20.49, Velocity Standard Deviation: 41.73,
# #4 = Pressure Mean: 0.43, Pressure Standard Deviation: 0.12, Velocity Mean: 21.19, Velocity Standard Deviation: 42.98,
# #5 = Pressure Mean: 0.45, Pressure Standard Deviation: 0.12, Velocity Mean: 32.27, Velocity Standard Deviation: 56.86,
# #6 = Pressure Mean: 0.43, Pressure Standard Deviation: 0.09, Velocity Mean: 27.38, Velocity Standard Deviation: 51.76,
# #7 = Pressure Mean: 0.48, Pressure Standard Deviation: 0.11, Velocity Mean: 30.10, Velocity Standard Deviation: 57.03,
# #8 = Pressure Mean: 0.40, Pressure Standard Deviation: 0.11, Velocity Mean: 26.62, Velocity Standard Deviation: 49.32,
# #9 = Pressure Mean: 0.32, Pressure Standard Deviation: 0.20, Velocity Mean: 18.06, Velocity Standard Deviation: 38.77,
# #10 = Pressure Mean: 0.40, Pressure Standard Deviation: 0.09, Velocity Mean: 22.91, Velocity Standard Deviation: 44.33,
# #11 = Pressure Mean: 0.50, Pressure Standard Deviation: 0.13, Velocity Mean: 31.77, Velocity Standard Deviation: 60.66,
# #12 = Pressure Mean: 0.43, Pressure Standard Deviation: 0.10, Velocity Mean: 16.84, Velocity Standard Deviation: 37.80,
# #13 = Pressure Mean: 0.35, Pressure Standard Deviation: 0.09, Velocity Mean: 23.76, Velocity Standard Deviation: 44.45,
# #14 = Pressure Mean: 0.40, Pressure Standard Deviation: 0.10, Velocity Mean: 24.90, Velocity Standard Deviation: 49.83,
# #15 = Pressure Mean: 0.40, Pressure Standard Deviation: 0.10, Velocity Mean: 17.85, Velocity Standard Deviation: 38.31,
# #16 = Pressure Mean: 0.41, Pressure Standard Deviation: 0.12, Velocity Mean: 18.12, Velocity Standard Deviation: 37.79,
# #17 = Pressure Mean: 0.40, Pressure Standard Deviation: 0.11, Velocity Mean: 18.14, Velocity Standard Deviation: 36.17,
# #18 = Pressure Mean: 0.41, Pressure Standard Deviation: 0.09, Velocity Mean: 16.51, Velocity Standard Deviation: 33.29,
# #19 = Pressure Mean: 0.38, Pressure Standard Deviation: 0.09, Velocity Mean: 35.49, Velocity Standard Deviation: 66.85,
# #20 = Pressure Mean: 0.38, Pressure Standard Deviation: 0.12, Velocity Mean: 22.79, Velocity Standard Deviation: 44.92,
# #21 = Pressure Mean: 0.41, Pressure Standard Deviation: 0.09, Velocity Mean: 24.58, Velocity Standard Deviation: 51.56,
# #22 = Pressure Mean: 0.35, Pressure Standard Deviation: 0.08, Velocity Mean: 5.82, Velocity Standard Deviation: 16.15,
# #23 = Pressure Mean: 0.36, Pressure Standard Deviation: 0.10, Velocity Mean: 26.10, Velocity Standard Deviation: 52.83,
# #24 = Pressure Mean: 0.35, Pressure Standard Deviation: 0.11, Velocity Mean: 21.97, Velocity Standard Deviation: 43.80,
# #25 = Pressure Mean: 0.37, Pressure Standard Deviation: 0.08, Velocity Mean: 24.83, Velocity Standard Deviation: 49.74,
# #26 = Pressure Mean: 0.30, Pressure Standard Deviation: 0.08, Velocity Mean: 23.43, Velocity Standard Deviation: 46.22,
# #27 = Pressure Mean: 0.40, Pressure Standard Deviation: 0.13, Velocity Mean: 22.92, Velocity Standard Deviation: 47.66,
# #28 = Pressure Mean: 0.42, Pressure Standard Deviation: 0.10, Velocity Mean: 21.14, Velocity Standard Deviation: 43.13,
# #29 = Pressure Mean: 0.37, Pressure Standard Deviation: 0.10, Velocity Mean: 19.68, Velocity Standard Deviation: 43.88,

# %% [markdown]
# This is the last Individual Impostor word written "labs" with the following statistics:
# | Statistics |      Pressure     |  Velocity |
# |----------|:-------------:|------:|
# | Mean |  0.37 | 19.68 |
# | Standard Deviation |    0.10   |   43.88 |

# %% [markdown]
# ### Plotting Normal Distribution Graphs for Impostor Pressure and Velocity

# %%
# Plot for Pressure
plt.figure(figsize=(10,5))
x = np.arange(min(stats_measures[:, 2]), max(stats_measures[:, 2]), 0.00125)
x_pdf = norm.pdf(x, loc=np.mean(stats_measures[:, 2]), scale=np.std(stats_measures[:, 2]))
plt.xlabel('Pressure')
plt.ylabel('Probability Density')
plt.title('Normal Distribution of Genuine Pressure')
plt.plot(x, x_pdf)

# Plot for Velocity
plt.figure(figsize=(10,5))
x = np.arange(min(stats_measures[:, 0]), max(stats_measures[:, 0]), 0.01)
x_pdf = norm.pdf(x, loc=np.mean(stats_measures[:, 0]), scale=np.std(stats_measures[:, 0]))
plt.xlabel('Velocity')
plt.ylabel('Probability Density')
plt.title('Normal Distribution of Genuine Velocity')
plt.plot(x, x_pdf)

# %% [markdown]
# Comparing both the genuine and impostor statistical data we can see the mean pressure for genuine word is higher 0.51 compared to the impostor word which is 0.37. The mean velocity is also higher for the genuine word than the impostor word 19.68. The standard deviation for both the genuine and impostor word is the same for pressure 0.10 but for velocity, the standard deviation is higher for the impostor word 43.88 compared to the genuine word 60.99. This means that there is greater variability in the speed of writing the word for the genuine data. The Genuine Pressure Distribution plot is centered around a mean value with a moderate spread, as indicated by the standard deviation. The Impostor Pressure Distribution , while still resembling a bell curve, seems to be more narrowly distributed and possibly with a peak that is off-center from the mean. Both Genuine and Impostor Velocity Distribution plots have a bell shaped curved with both not being centered which could mean that the normal distribution has a wide spread because of the high standard deviation. The genuine data exhibit a wider range of velocities, possibly indicating a more fluid and natural signing process with variations in speed. The Impostor has a lower mean velocity and also less variability in velocity, which we can reach a conclusion that a more cautious process was used to write the word to mimic someone else's writing.

# %% [markdown]
# ## Conclusion

# %% [markdown]
# One of the purposes of this lab is to become acquainted with statistical analysis. From the first exercise we can visually see the effect sample size has on distribution and variability, in this case, standard deviation. In exercise 2 we are able to graphically recreate the signature using a pen pressure color map and graph the distribution of pressure, as well as note down the mean and standard deviation. From this exercise we learnt that the probability density function uses statistical analysis to predict the likelihood of different pressure levels. In exercise 3, we can take away why the difference in time must not be equal to zero, as it causes an error in the program; using that knowledge allows us to create a velocity color map of the sample signature. Additionally, we plotted the pen pressure signature in 3D, relating back to the normal distribution graph, we can now take away how both graphs correlate. From exercise 4 and 5 we can see the contrast of pressure and velocity through both normal distribution graphs. For example, the peak of the pressure graph is around 17 probability density for the genuine signature, whereas it was around 9 probability density for the imposter signature. whereas the These two exercises utilize the findings from the previous exercises to allow us to draw up these conclusions and allow us to fulfill the purpose of verification/recognition of genuine and imposter signatures.
